# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
print(tf.__version__)
# Out:
# 2.7.0

# %%
df = pd.read_csv('/content/drive/MyDrive/Korea_Apt_Data/0.csv')

# %%
df.head(5)
# Out:
#    Unnamed: 0  ...  sell_unit_price_sidanji_gap
# 0      852646  ...                 -1499.507619
# 1      198665  ...                   465.785299
# 2      544294  ...                 -1338.213068
# 3      538274  ...                  -825.944564
# 4      107715  ...                  1290.212365
#
# [5 rows x 254 columns]

# %%
df = df.drop(columns = ['Unnamed: 0'])

# %%
df.head(5)
# Out:
#    q_all_sell_unit_price_danji  ...  sell_unit_price_sidanji_gap
# 0                           62  ...                 -1499.507619
# 1                           49  ...                   465.785299
# 2                           85  ...                 -1338.213068
# 3                           80  ...                  -825.944564
# 4                           48  ...                  1290.212365
#
# [5 rows x 253 columns]

# %%
df
# Out:
#         q_all_sell_unit_price_danji  ...  sell_unit_price_sidanji_gap
# 0                                62  ...                 -1499.507619
# 1                                49  ...                   465.785299
# 2                                85  ...                 -1338.213068
# 3                                80  ...                  -825.944564
# 4                                48  ...                  1290.212365
# ...                             ...  ...                          ...
# 114633                           46  ...                   631.901115
# 114634                           38  ...                   469.345446
# 114635                           81  ...                  -975.984229
# 114636                           47  ...                   131.273677
# 114637                           78  ...                 -2124.829835
#
# [114638 rows x 253 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of         q_all_sell_unit_price_danji  ...  sell_unit_price_sidanji_gap
# 0                                62  ...                 -1499.507619
# 1                                49  ...                   465.785299
# 2                                85  ...                 -1338.213068
# 3                                80  ...                  -825.944564
# 4                                48  ...                  1290.212365
# ...                             ...  ...                          ...
# 114633                           46  ...                   631.901115
# 114634                           38  ...                   469.345446
# 114635                           81  ...                  -975.984229
# 114636                           47  ...                   131.273677
# 114637                           78  ...                 -2124.829835
#
# [114638 rows x 253 columns]>

# %%
df.describe()
# Out:
#        q_all_sell_unit_price_danji  ...  sell_unit_price_sidanji_gap
# count                114638.000000  ...                114638.000000
# mean                     44.534387  ...                   -37.951996
# std                      26.858152  ...                  1109.448300
# min                       0.000000  ...                -15119.149840
# 25%                      22.000000  ...                  -382.190160
# 50%                      43.000000  ...                   155.385467
# 75%                      66.000000  ...                   569.326202
# max                      99.000000  ...                  2976.671043
#
# [8 rows x 253 columns]

# %%
# sns.heatmap(df.isnull())

# %%
df['sell_unit_price_sidanji_gap'].plot(linewidth = 0.1)

# %%
X = df.iloc[:, :-1].values
Y = df.iloc[:, -1:].values

# %%
X.shape
# Out:
# (114638, 252)

# %%
Y.shape
# Out:
# (114638, 1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler_X = MinMaxScaler()
scaler_Y = MinMaxScaler()
Y = scaler_Y.fit_transform(Y)
X = scaler_X.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
X_train.shape
# Out:
# (91710, 252)

# %%
X_test.shape
# Out:
# (22928, 252)

# %%
X_train
# Out:
# array([[0.08080808, 0.13131313, 0.46464646, ..., 0.43529412, 0.43181818,
#         0.01149425],
#        [0.78787879, 0.93939394, 0.88888889, ..., 0.62352941, 0.32954545,
#         0.04597701],
#        [0.76767677, 0.60606061, 0.74747475, ..., 0.45882353, 0.39772727,
#         0.35632184],
#        ...,
#        [0.74747475, 0.57575758, 0.68686869, ..., 0.        , 0.        ,
#         0.        ],
#        [0.31313131, 0.51515152, 0.33333333, ..., 0.94117647, 0.55681818,
#         0.08045977],
#        [0.54545455, 0.32323232, 0.31313131, ..., 0.85882353, 0.82954545,
#         0.59770115]])

# %%
Y_train
# Out:
# array([[0.88195508],
#        [0.76542146],
#        [0.81721555],
#        ...,
#        [0.80720951],
#        [0.84592819],
#        [0.86205796]])

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units = 500, activation = 'relu', input_shape = (252, )))
model.add(tf.keras.layers.Dense(units = 500, activation = 'relu'))
model.add(tf.keras.layers.Dense(units = 500, activation = 'relu'))
model.add(tf.keras.layers.Dense(units = 1, activation = 'linear'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 500)               126500
#
#  dense_1 (Dense)             (None, 500)               250500
#
#  dense_2 (Dense)             (None, 500)               250500
#
#  dense_3 (Dense)             (None, 1)                 501
#
# =================================================================
# Total params: 628,001
# Trainable params: 628,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'Adam', loss = 'mean_squared_error')

# %%
epochs_hist = model.fit( X_train, Y_train, epochs = 20, batch_size = 50, validation_split= 0.2 )
# Out:
# Epoch 1/20
# 1468/1468 [==============================] - 9s 5ms/step - loss: 0.0033 - val_loss: 7.6682e-04
# Epoch 2/20
# 1468/1468 [==============================] - 6s 4ms/step - loss: 7.0969e-04 - val_loss: 5.3698e-04
# Epoch 3/20
# 1468/1468 [==============================] - 7s 5ms/step - loss: 5.7660e-04 - val_loss: 5.9812e-04
# Epoch 4/20
# 1468/1468 [==============================] - 6s 4ms/step - loss: 4.9996e-04 - val_loss: 6.1266e-04
# Epoch 5/20
# 1468/1468 [==============================] - 6s 4ms/step - loss: 4.7423e-04 - val_loss: 4.3766e-04
# Epoch 6/20
# 1468/1468 [==============================] - 7s 5ms/step - loss: 4.6361e-04 - val_loss: 4.7914e-04
# Epoch 7/20
# 1468/1468 [==============================] - 7s 5ms/step - loss: 4.4159e-04 - val_loss: 4.3089e-04
# Epoch 8/20
# 1468/1468 [==============================] - 7s 5ms/step - loss: 4.2726e-04 - val_loss: 4.1616e-04
# Epoch 9/20
# 1468/1468 [==============================] - 6s 4ms/step - loss: 4.0815e-04 - val_loss: 4.0563e-04
# Epoch 10/20
# 1468/1468 [==============================] - 7s 5ms/step - loss: 3.9356e-04 - val_loss: 4.3236e-04
# Epoch 11/20
# 1468/1468 [==============================] - 6s 4ms/step - loss: 3.8627e-04 - val_loss: 4.5596e-04
# Epoch 12/20
# 1468/1468 [==============================] - 6s 4ms/step - loss: 3.7412e-04 - val_loss: 4.4768e-04
# Epoch 13/20
# 1468/1468 [==============================] - 6s 4ms/step - loss: 3.7390e-04 - val_loss: 4.4075e-04
# Epoch 14/20
# 1468/1468 [==============================] - 6s 4ms/step - loss: 3.7555e-04 - val_loss: 3.9449e-04
# Epoch 15/20
# 1468/1468 [==============================] - 6s 4ms/step - loss: 3.5680e-04 - val_loss: 4.4108e-04
# Epoch 16/20
# 1468/1468 [==============================] - 6s 4ms/step - loss: 3.5565e-04 - val_loss: 3.6014e-04
# Epoch 17/20
# 1468/1468 [==============================] - 6s 4ms/step - loss: 3.5238e-04 - val_loss: 4.1431e-04
# Epoch 18/20
# 1468/1468 [==============================] - 6s 4ms/step - loss: 3.5440e-04 - val_loss: 3.7273e-04
# Epoch 19/20
# 1468/1468 [==============================] - 6s 4ms/step - loss: 3.5076e-04 - val_loss: 3.8697e-04
# Epoch 20/20
# 1468/1468 [==============================] - 6s 4ms/step - loss: 3.4080e-04 - val_loss: 3.6644e-04

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])

plt.title('Model Loss Progress During Training')
plt.xlabel('Epochs')
plt.ylabel('Training and Validation Loss')
# Out:
# Text(0, 0.5, 'Training and Validation Loss')

# %%
y_predict = model.predict(X_test)
plt.plot(Y_test, y_predict, '^', color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
# Out:
# Text(0, 0.5, 'True Values')

# %%
 y_predict_orig = scaler_Y.inverse_transform(y_predict)

# %% [markdown]
# need two scaler

# %%
 y_test_orig = scaler_Y.inverse_transform(Y_test)

# %%
plt.plot(y_test_orig, y_predict_orig, '^', color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
# Out:
# Text(0, 0.5, 'True Values')
