# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
print(tf.__version__)
# Out:
# 2.7.0

# %%
df = pd.read_csv('/content/drive/MyDrive/Korea_Apt_Data/0.csv')

# %%
df.head(5)
# Out:
#    Unnamed: 0  ...  sell_unit_price_sidanji_gap
# 0      852646  ...                 -1499.507619
# 1      198665  ...                   465.785299
# 2      544294  ...                 -1338.213068
# 3      538274  ...                  -825.944564
# 4      107715  ...                  1290.212365
#
# [5 rows x 254 columns]

# %%
df = df.drop(columns = ['Unnamed: 0'])

# %%
df.head(5)
# Out:
#    q_all_sell_unit_price_danji  ...  sell_unit_price_sidanji_gap
# 0                           62  ...                 -1499.507619
# 1                           49  ...                   465.785299
# 2                           85  ...                 -1338.213068
# 3                           80  ...                  -825.944564
# 4                           48  ...                  1290.212365
#
# [5 rows x 253 columns]

# %%
df
# Out:
#         q_all_sell_unit_price_danji  ...  sell_unit_price_sidanji_gap
# 0                                62  ...                 -1499.507619
# 1                                49  ...                   465.785299
# 2                                85  ...                 -1338.213068
# 3                                80  ...                  -825.944564
# 4                                48  ...                  1290.212365
# ...                             ...  ...                          ...
# 114633                           46  ...                   631.901115
# 114634                           38  ...                   469.345446
# 114635                           81  ...                  -975.984229
# 114636                           47  ...                   131.273677
# 114637                           78  ...                 -2124.829835
#
# [114638 rows x 253 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of         q_all_sell_unit_price_danji  ...  sell_unit_price_sidanji_gap
# 0                                62  ...                 -1499.507619
# 1                                49  ...                   465.785299
# 2                                85  ...                 -1338.213068
# 3                                80  ...                  -825.944564
# 4                                48  ...                  1290.212365
# ...                             ...  ...                          ...
# 114633                           46  ...                   631.901115
# 114634                           38  ...                   469.345446
# 114635                           81  ...                  -975.984229
# 114636                           47  ...                   131.273677
# 114637                           78  ...                 -2124.829835
#
# [114638 rows x 253 columns]>

# %%
df.describe()
# Out:
#        q_all_sell_unit_price_danji  ...  sell_unit_price_sidanji_gap
# count                114638.000000  ...                114638.000000
# mean                     44.534387  ...                   -37.951996
# std                      26.858152  ...                  1109.448300
# min                       0.000000  ...                -15119.149840
# 25%                      22.000000  ...                  -382.190160
# 50%                      43.000000  ...                   155.385467
# 75%                      66.000000  ...                   569.326202
# max                      99.000000  ...                  2976.671043
#
# [8 rows x 253 columns]

# %%
sns.heatmap(df.isnull())

# %%
df['sell_unit_price_sidanji_gap'].plot(linewidth = 0.1)

# %%
X = df.iloc[:, :-1].values
Y = df.iloc[:, -1:].values

# %%
X.shape
# Out:
# (114638, 252)

# %%
Y.shape
# Out:
# (114638, 1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
Y = scaler.fit_transform(Y)
X = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
X_train.shape
# Out:
# (91710, 252)

# %%
X_test.shape
# Out:
# (22928, 252)

# %%
X_train
# Out:
# array([[0.57575758, 0.80808081, 0.55555556, ..., 0.83529412, 0.57954545,
#         0.26436782],
#        [0.68686869, 0.88888889, 0.91919192, ..., 0.95294118, 0.85227273,
#         0.66666667],
#        [0.87878788, 0.7979798 , 0.42424242, ..., 0.12941176, 0.17045455,
#         0.11494253],
#        ...,
#        [0.65656566, 0.86868687, 0.19191919, ..., 0.        , 0.        ,
#         0.        ],
#        [0.33333333, 0.55555556, 0.50505051, ..., 0.51764706, 0.47727273,
#         0.33333333],
#        [0.12121212, 0.19191919, 0.11111111, ..., 0.15294118, 0.25      ,
#         0.12643678]])

# %%
Y_train
# Out:
# array([[0.80044731],
#        [0.85579163],
#        [0.71569236],
#        ...,
#        [0.75933814],
#        [0.83951395],
#        [0.85260214]])

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units = 500, activation = 'relu', input_shape = (252, )))
model.add(tf.keras.layers.Dense(units = 500, activation = 'relu'))
model.add(tf.keras.layers.Dense(units = 500, activation = 'relu'))
model.add(tf.keras.layers.Dense(units = 1, activation = 'linear'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 500)               126500
#
#  dense_5 (Dense)             (None, 500)               250500
#
#  dense_6 (Dense)             (None, 500)               250500
#
#  dense_7 (Dense)             (None, 1)                 501
#
# =================================================================
# Total params: 628,001
# Trainable params: 628,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'Adam', loss = 'mean_squared_error')

# %%
epochs_hist = model.fit( X_train, Y_train, epochs = 20, batch_size = 50 )
# Out:
# Epoch 1/20
# 1835/1835 [==============================] - 9s 4ms/step - loss: 0.0034
# Epoch 2/20
# 1835/1835 [==============================] - 7s 4ms/step - loss: 6.3763e-04
# Epoch 3/20
# 1835/1835 [==============================] - 7s 4ms/step - loss: 5.5028e-04
# Epoch 4/20
# 1835/1835 [==============================] - 7s 4ms/step - loss: 4.9059e-04
# Epoch 5/20
# 1835/1835 [==============================] - 7s 4ms/step - loss: 4.6645e-04
# Epoch 6/20
# 1835/1835 [==============================] - 7s 4ms/step - loss: 4.5215e-04
# Epoch 7/20
# 1835/1835 [==============================] - 7s 4ms/step - loss: 4.2572e-04
# Epoch 8/20
# 1835/1835 [==============================] - 6s 4ms/step - loss: 4.2632e-04
# Epoch 9/20
# 1835/1835 [==============================] - 7s 4ms/step - loss: 3.9555e-04
# Epoch 10/20
# 1835/1835 [==============================] - 7s 4ms/step - loss: 3.8852e-04
# Epoch 11/20
# 1835/1835 [==============================] - 7s 4ms/step - loss: 3.7392e-04
# Epoch 12/20
# 1835/1835 [==============================] - 8s 5ms/step - loss: 3.7580e-04
# Epoch 13/20
# 1835/1835 [==============================] - 7s 4ms/step - loss: 3.6587e-04
# Epoch 14/20
# 1835/1835 [==============================] - 7s 4ms/step - loss: 3.5980e-04
# Epoch 15/20
# 1835/1835 [==============================] - 7s 4ms/step - loss: 3.5331e-04
# Epoch 16/20
# 1835/1835 [==============================] - 7s 4ms/step - loss: 3.5234e-04
# Epoch 17/20
# 1835/1835 [==============================] - 6s 4ms/step - loss: 3.5151e-04
# Epoch 18/20
# 1835/1835 [==============================] - 7s 4ms/step - loss: 3.4781e-04
# Epoch 19/20
# 1835/1835 [==============================] - 7s 4ms/step - loss: 3.4636e-04
# Epoch 20/20
# 1835/1835 [==============================] - 7s 4ms/step - loss: 3.3533e-04
