# %%
import pandas as pd

# %%
X_df = pd.read_csv('C:/Users/JIN XI/Downloads/X_Without_q_Droped.csv')
Y_df = pd.read_csv('C:/Users/JIN XI/Downloads/12M_data/Y_sell_unit_price_sidanji_gap_12shifted.csv')

# %%
pd.set_option('display.max_columns',253)
pd.set_option('display.max_rows', 10)

# %%
X_df.head()
# Out:
#    Unnamed: 0  q_all_sell_unit_price_danji  q_si_sell_unit_price_danji  \
# 0           0                           89                          81
# 1           1                           88                          80
# 2           2                           88                          79
# 3           3                           87                          78
# 4           4                           86                          77
#
#    q_gu_sell_unit_price_danji  q_dong_sell_unit_price_danji  \
# 0                          47                            43
# 1                          45                            41
# 2                          43                            39
# 3                          41                            37
# 4                          39                            35
#
#    q_all_rent_unit_price_danji  q_si_rent_unit_price_danji  \
# 0                           73                          57
# ...

# %%
Y_df.head()
# Out:
#    Unnamed: 0  sell_unit_price_sidanji_gap
# 0           0                  -570.607793
# 1           1                  -614.800277
# 2           2                  -659.476708
# 3           3                  -705.841233
# 4           4                  -754.297240

# %%
X_df.shape
# Out:
# (1643616, 253)

# %%
Y_df.shape
# Out:
# (1643616, 2)

# %%
Y_df['sell_unit_price_sidanji_gap']
# Out:
# 0         -570.607793
# 1         -614.800277
# 2         -659.476708
# 3         -705.841233
# 4         -754.297240
#               ...
# 1643611           NaN
# 1643612           NaN
# 1643613           NaN
# 1643614           NaN
# 1643615           NaN
# Name: sell_unit_price_sidanji_gap, Length: 1643616, dtype: float64

# %%
X_df['sell_unit_price_sidanji_gap'] = Y_df['sell_unit_price_sidanji_gap']

# %%
X_df.head()
# Out:
#    Unnamed: 0  q_all_sell_unit_price_danji  q_si_sell_unit_price_danji  \
# 0           0                           89                          81
# 1           1                           88                          80
# 2           2                           88                          79
# 3           3                           87                          78
# 4           4                           86                          77
#
#    q_gu_sell_unit_price_danji  q_dong_sell_unit_price_danji  \
# 0                          47                            43
# 1                          45                            41
# 2                          43                            39
# 3                          41                            37
# 4                          39                            35
#
#    q_all_rent_unit_price_danji  q_si_rent_unit_price_danji  \
# 0                           73                          57
# ...

# %%
# Out:
#          Unnamed: 0  q_all_sell_unit_price_danji  q_si_sell_unit_price_danji  \
# 0                 0                           89                          81
# 1                 1                           88                          80
# 2                 2                           88                          79
# 3                 3                           87                          78
# 4                 4                           86                          77
# ...             ...                          ...                         ...
# 1643575     1643575                           10                          56
# 1643576     1643576                            4                          29
# 1643577     1643577                           10                          54
# 1643578     1643578                           10                          55
# 1643579     1643579                            9                          53
#
# ...

# %%
X_df.to_csv('C:/Users/JIN XI/Downloads/12M_data/Final.csv')

# %%
Final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1643616 entries, 0 to 1643615
# Columns: 254 entries, Unnamed: 0 to sell_unit_price_sidanji_gap
# dtypes: float64(10), int64(244)
# memory usage: 3.1 GB
