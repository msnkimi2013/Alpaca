# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_35674/2348078178.py in <module>
# ----> 1 import tensorflow as tf
#       2 import pandas as pd
#       3 import numpy as np
#       4 import seaborn as sns
#       5 import matplotlib.pyplot as plt
#
# ~/anaconda3/envs/tf2_gpu/lib/python3.8/site-packages/tensorflow/__init__.py in <module>
#      39 import sys as _sys
#      40
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      43
#
# ~/anaconda3/envs/tf2_gpu/lib/python3.8/site-packages/tensorflow/python/__init__.py in <module>
#      47 from tensorflow.python import distribute
#      48 # from tensorflow.python import keras
# ---> 49 from tensorflow.python.feature_column import feature_column_lib as feature_column
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/Korea_Apt_Data/Final_1.csv')

# %%
df = df.drop(columns = ['Unnamed: 0'])
